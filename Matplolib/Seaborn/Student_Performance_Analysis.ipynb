# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('Student_Performance_Analysis.xlsx')
data.head()
# Out:
#   Student_ID  Gender  Department  Study_Hours  Attendance  Assignments  \
# 0       S001    Male         CSE            2          75            6
# 1       S002  Female          IT            4          85            8
# 2       S003    Male         ECE            3          80            7
# 3       S004  Female         CSE            5          92           10
# 4       S005    Male  Mechanical            1          65            4
#
#    Midterm_Marks  Final_Marks
# 0             45           50
# 1             60           68
# 2             55           61
# 3             78           84
# 4             35           40

# %%
data.columns
# Out:
# Index(['Student_ID', 'Gender', 'Department', 'Study_Hours', 'Attendance',
#        'Assignments', 'Midterm_Marks', 'Final_Marks'],
#       dtype='object')

# %%
sns.scatterplot(data=data, x='Study_Hours', y='Final_Marks')

plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student_ID     20 non-null     object
#  1   Gender         20 non-null     object
#  2   Department     20 non-null     object
#  3   Study_Hours    20 non-null     int64
#  4   Attendance     20 non-null     int64
#  5   Assignments    20 non-null     int64
#  6   Midterm_Marks  20 non-null     int64
#  7   Final_Marks    20 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 1.4+ KB

# %%
###  line plot
#  show trends growth or decline over a peroid

# %%
sns.lineplot(data=data,x='Study_Hours',y='Final_Marks')
plt.title('Sutydy vs FinalMarks')
plt.show()

# %%
sns.barplot(data=data,x='Department',y='Final_Marks')
plt.show()

# %%
sns.barplot(data=data,x='Gender',y='Final_Marks')
plt.show()

# %%
sns.barplot(data=data,x='Study_Hours',y='Final_Marks')
plt.show()

# %%
## Count Plot

# %%
sns.countplot(data=data,x='Department')
plt.show()

# %%
## Histogram

# %%
sns.boxplot(data=data,x='Gender',y='Final_Marks')
plt.show()

# %%
##  Histogram

# %%
sns.histplot(data=data,x='Final_Marks' , bins=8)
plt.show()

# %%
###Violin Plot

# %%
sns.violinplot(data=data,x='Gender',y='Final_Marks')
plt.show()
