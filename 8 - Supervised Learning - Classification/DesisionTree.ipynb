# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data={
    'Gender':['F','F','M','F','M','M'],
    'Profile':['HR','Developer', 'Developer','Developer','HR','HR'],
    'Job Role':['Hiring','APP','WEB','APP','Hiring','Hiring']}
df=pd.DataFrame(data)
df
# Out:
#   Gender    Profile Job Role
# 0      F         HR   Hiring
# 1      F  Developer      APP
# 2      M  Developer      WEB
# 3      F  Developer      APP
# 4      M         HR   Hiring
# 5      M         HR   Hiring

# %%
df = pd.read_csv("Loan_Approval_Prediction.csv")

# %%
df.head()
# Out:
#    Customer ID Income Level Credit Score     Employment Existing Loan  \
# 0            1         High    Excellent      Permanent            No
# 1            2          Low         Poor      Temporary           Yes
# 2            3       Medium         Good      Permanent            No
# 3            4       Medium         Fair  Self-Employed           Yes
# 4            5         High         Good      Permanent            No
#
#   Property Loan Approved
# 0      Own           Yes
# 1     Rent            No
# 2      Own           Yes
# 3     Rent            No
# 4      Own           Yes

# %%
num_data={
    'Age':[22,35,45,30,25],
     'Salary':[20000,50000,80000,40000,25000],
    'Purchased':[0,1,1,0,0]}

# %%
num_data=pd.DataFrame(num_data)
num_data
# Out:
#    Age  Salary  Purchased
# 0   22   20000          0
# 1   35   50000          1
# 2   45   80000          1
# 3   30   40000          0
# 4   25   25000          0

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
df=df.drop("Customer ID",axis=1)
df
# Out:
#    Income Level Credit Score     Employment Existing Loan Property  \
# 0          High    Excellent      Permanent            No      Own
# 1           Low         Poor      Temporary           Yes     Rent
# 2        Medium         Good      Permanent            No      Own
# 3        Medium         Fair  Self-Employed           Yes     Rent
# 4          High         Good      Permanent            No      Own
# 5           Low         Fair      Temporary           Yes     Rent
# 6          High    Excellent  Self-Employed            No      Own
# 7        Medium         Good      Permanent           Yes      Own
# 8           Low         Poor      Temporary           Yes     Rent
# 9        Medium    Excellent      Permanent            No      Own
# 10         High         Fair  Self-Employed            No      Own
# 11          Low         Good      Permanent           Yes     Rent
# 12       Medium         Fair      Permanent            No     Rent
# ...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df_encoded = df.copy()

for column in df.columns:
    df_encoded[column] = encoder.fit_transform(df[column])

df_encoded.head()
# Out:
#    Income Level  Credit Score  Employment  Existing Loan  Property  \
# 0             0             0           0              0         0
# 1             1             3           2              1         1
# 2             2             2           0              0         0
# 3             2             1           1              1         1
# 4             0             2           0              0         0
#
#    Loan Approved
# 0              1
# 1              0
# 2              1
# 3              0
# 4              1

# %%
X=df_encoded.drop("Loan Approved", axis=1)
y=df_encoded["Loan Approved"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
model=DecisionTreeClassifier(criterion="entropy",random_state=42)

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %%
y_pred =model.predict(X_test)
print(y_pred)
# Out:
# [1 0 1 0]

# %%
comparision =pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
comparision
# Out:
#     Actual  Predicted
# 0        1          1
# 17       0          0
# 15       1          1
# 1        0          0

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
df_encoded.head(1)
# Out:
# Accuracy: 1.0
#    Income Level  Credit Score  Employment  Existing Loan  Property  \
# 0             0             0           0              0         0
#
#    Loan Approved
# 0              1

# %%
new_customer=pd.DataFrame({
    "Income Level":[1],
    "Credit Score":[3],
    "Employment":[0],
    "Existing Loan":[0],
    "Property":[1]
})
prediction=model.predict(new_customer)
print(prediction)
# Out:
# [1]
