# %%
import numpy as np

# %%
arr1 = np.array([[4,6],[8,10]])
arr2 = np.array([[2,4],[6,8]])

# %%
print(arr1)
print(arr2)
# Out:
# [[ 4  6]
#  [ 8 10]]
# [[2 4]
#  [6 8]]

# %%
print(arr1 + arr2)
# Out:
# [[ 6 10]
#  [14 18]]

# %%
print(arr1 - arr2)
# Out:
# [[2 2]
#  [2 2]]

# %%
print(arr1 * arr2)
# Out:
# [[ 8 24]
#  [48 80]]

# %%
print(arr1 / arr2)
# Out:
# [[2.         1.5       ]
#  [1.33333333 1.25      ]]

# %%
print(arr1 @ arr2)
# Out:
# [[ 44  64]
#  [ 76 112]]
